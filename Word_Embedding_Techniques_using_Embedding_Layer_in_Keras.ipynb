# %% [markdown]
# ## Word Embedding Techniques using Embedding Layer in Keras

# %%
##tensorflow >2.0
from tensorflow.keras.preprocessing.text import one_hot

# %%
# Sentences
Sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'understand the meaning of words',
        'South America is the fourth largest country',]

# %%
Sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'understand the meaning of words',
#  'South America is the fourth largest country']

# %%
### Vocabulary size
voc_size = 10000

# %% [markdown]
# ***One hot representation***

# %%
one_hot_repr = [one_hot(words,voc_size)for words in Sent]
print(one_hot_repr)
# Out:
# [[7934, 9631, 4928, 8291], [7934, 9631, 4928, 706], [7934, 8892, 4928, 494], [3586, 3322, 9082, 8420, 6786], [8237, 7934, 8212, 4928, 4661], [507, 400, 1348, 7934, 187, 7261, 8332]]

# %% [markdown]
# **WORD Embedding Representation**

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_lenght = 10
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_lenght)
print(embedded_docs)
# Out:
# [[   0    0    0    0    0    0 7934 9631 4928 8291]
#  [   0    0    0    0    0    0 7934 9631 4928  706]
#  [   0    0    0    0    0    0 7934 8892 4928  494]
#  [   0    0    0    0    0 3586 3322 9082 8420 6786]
#  [   0    0    0    0    0 8237 7934 8212 4928 4661]
#  [   0    0    0  507  400 1348 7934  187 7261 8332]]

# %%
dim =10

# %%
model = Sequential()
model.add(Embedding(voc_size,12,input_length=sent_lenght))
model.compile("adam", "mse")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 12)            120000
# =================================================================
# Total params: 120,000
# Trainable params: 120,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model.predict(embedded_docs))
# Out:
# [[[ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [-0.01387974  0.03135752 -0.03246009 -0.00759978 -0.01011951
#     0.01049626  0.01508485  0.00110012  0.02097826 -0.03792375
#     0.00290642  0.01922014]
#   [ 0.04922972  0.04762156 -0.02319671  0.02643219  0.0433215
#     0.00105256 -0.03271989 -0.0002468  -0.01183438  0.04705688
#     0.02490493  0.01941465]
#   [ 0.01246462  0.01117581 -0.00182662  0.03892906  0.02844093
#     0.04275565 -0.04465768  0.04215486  0.04488343 -0.00412279
#    -0.03822005  0.02991024]
#   [ 0.04011318 -0.02688155 -0.00925193 -0.04950113  0.00495341
#    -0.04825597 -0.01758078  0.00658816  0.04368453 -0.04430565
#    -0.02358834  0.03807998]]
#
#  [[ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [-0.01387974  0.03135752 -0.03246009 -0.00759978 -0.01011951
#     0.01049626  0.01508485  0.00110012  0.02097826 -0.03792375
#     0.00290642  0.01922014]
#   [ 0.04922972  0.04762156 -0.02319671  0.02643219  0.0433215
#     0.00105256 -0.03271989 -0.0002468  -0.01183438  0.04705688
#     0.02490493  0.01941465]
#   [ 0.01246462  0.01117581 -0.00182662  0.03892906  0.02844093
#     0.04275565 -0.04465768  0.04215486  0.04488343 -0.00412279
#    -0.03822005  0.02991024]
#   [-0.04773613 -0.04522727  0.02732587 -0.0227178  -0.03386332
#    -0.03087199  0.0222769  -0.03923099  0.0424677   0.02244902
#     0.0335866   0.01502417]]
#
#  [[ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   
 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839
#     0.04530302  0.03718981 -0.04820434  0.01778633  0.00334017
#    -0.01935947 -0.01570432]
#   [-0.04554543 -0.0241582  -0.00342699  0.03764944  0.03947463
#     0.03829025  0.02888227 -0.02117717 -0.0091481  -0.02976967
#    -0.00081287  0.04809575]
#   [ 0.00617588 -0.03530438  0.0386354  -0.02726983 -0.01456354
#    -0.02364086  0.04308982  0.02767955 -0.00814408  0.03865058
#     0.01507132 -0.02314349]
#   [ 0.01868422 -0.02355081 -0.01552339 -0.01963241 -0.03998093
#    -0.04124125 -0.04643884 -0.011383   -0.00846304  0.00229702
#    -0.0288459   0.01586634]
#   [-0.01387974  0.03135752 -0.03246009 -0.00759978 -0.01011951
#     0.01049626  0.01508485  0.00110012  0.02097826 -0.03792375
#     0.00290642  0.01922014]
#   [-0.02142494  0.01448724  0.04488076 -0.0266943   0.03050579
#     0.02062135 -0.0459644   0.01694107 -0.02001828  0.01766086
#    -0.00595057  0.00155785]
#   [-0.00967675  0.0338174  -0.04478551  0.04424853  0.04992175
#     0.02155307  0.02470723 -0.01783779 -0.041282    0.0010283
#     0.03399909  0.01572086]
#   [-0.01803907 -0.00818237 -0.00679995 -0.00512928  0.02078572
#    -0.03911563  0.04404048 -0.01774751  0.00268324  0.00784745
#    -0.03570305 -0.00440868]]]

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,    0,    0, 7934, 9631, 4928, 8291],
#       dtype=int32)

# %%
print(model.predict(embedded_docs)[0])
# Out:
# [[ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839  0.04530302
#    0.03718981 -0.04820434  0.01778633  0.00334017 -0.01935947 -0.01570432]
#  [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839  0.04530302
#    0.03718981 -0.04820434  0.01778633  0.00334017 -0.01935947 -0.01570432]
#  [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839  0.04530302
#    0.03718981 -0.04820434  0.01778633  0.00334017 -0.01935947 -0.01570432]
#  [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839  0.04530302
#    0.03718981 -0.04820434  0.01778633  0.00334017 -0.01935947 -0.01570432]
#  [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839  0.04530302
#    0.03718981 -0.04820434  0.01778633  0.00334017 -0.01935947 -0.01570432]
#  [ 0.04990384  0.01940347 -0.04554195 -0.01175528 -0.02714839  0.04530302
#    0.03718981 -0.04820434  0.01778633  0.00334017 -0.01935947 -0.01570432]
#  [-0.01387974  0.03135752 -0.03246009 -0.00759978 -0.01011951  0.01049626
#    0.01508485  0.00110012  0.02097826 -0.03792375  0.00290642  0.01922014]
#  [ 0.04922972  0.04762156 -0.02319671  0.02643219  0.0433215   0.00105256
#   -0.03271989 -0.0002468  -0.01183438  0.04705688  0.02490493  0.01941465]
#  [ 0.01246462  0.01117581 -0.00182662  0.03892906  0.02844093  0.04275565
#   -0.04465768  0.04215486  0.04488343 -0.00412279 -0.03822005  0.02991024]
#  [ 0.04011318 -0.02688155 -0.00925193 -0.04950113  0.00495341 -0.04825597
#   -0.01758078  0.00658816  0.04368453 -0.04430565 -0.02358834  0.03807998]]
